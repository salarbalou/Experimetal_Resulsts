# %% [markdown]
# <a href="https://colab.research.google.com/github/salarbalou/Experimetal_Resulsts/blob/main/XRD_Analysis_CQDs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import requests as req
import regex as re
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.io as pio
from scipy import signal
from scipy.signal import find_peaks
pio.templates.default = 'plotly_white'

# %%
n =0

# %%
#dataB = np.loadtxt('https://raw.githubusercontent.com/salarbalou/Experimetal_Resulsts/main/XRD-BCQD.txt')
dataC = np.loadtxt('https://raw.githubusercontent.com/salarbalou/Experimetal_Resulsts/main/XRD-CCQD.txt')
dataG = np.loadtxt('https://raw.githubusercontent.com/salarbalou/Photothermal_Study_CQDs/main/XRD-OCQD.txt')
dataY = np.loadtxt('https://raw.githubusercontent.com/salarbalou/Experimetal_Resulsts/main/XRD-YCQD.txt')
dataR = np.loadtxt('https://raw.githubusercontent.com/salarbalou/Experimetal_Resulsts/main/XRD-RCQD.txt')

waveB, intentB  = dataC[:, 0], np.loadtxt('https://raw.githubusercontent.com/salarbalou/Experimetal_Resulsts/main/GCQDS.txt', delimiter = ',').reshape((7004, ))
waveC, intentC = dataC[:, 0], dataC[:, 1]
waveG, intentG = dataG[:, 0], dataG[:, 1]
waveY, intentY = dataY[:, 0], dataY[:, 1]
waveR, intentR = dataR[:, 0], dataR[:, 1]

#peaks = np.unique(np.array(wave[np.argmax(intent)], dtype = 'float64'))
#noise = np.random.normal(loc = 1, scale = 10**(-n), size = 7001)
r = 1500

L = 1.5406 #Wavelenght of incident X-ray
n = 1 #order of diffraction

#Peaks are manually selected
peaksB = np.array([25.64, 44.66])
peaksBI = np.squeeze(np.array([intentB[np.where(waveB == peaksB[i])[0]] for i in range(peaksB.size)])) #Corresponding intenstiy of the peaks

peaksC = np.array([26.68, 38.34, 44.68])
peaksCI = np.squeeze(np.array([intentC[np.where(waveC == peaksC[i])[0]] for i in range(peaksC.size)]))

peaksG = np.array([17.73, 18.49, 19.61, 38.41, 44.68])
peaksGI = np.squeeze(np.array([intentG[np.where(waveG == peaksG[i])[0]] for i in range(peaksG.size)]))

peaksY = np.array([17.68, 19.61, 26.21, 30.93, 38.42, 44.68])
peaksYI = np.squeeze(np.array([intentY[np.where(waveY == peaksY[i])[0]] for i in range(peaksY.size)]))

peaksR = np.array([21.69, 38.44, 44.69])
peaksRI = np.squeeze(np.array([intentR[np.where(waveR == peaksR[i])[0]] for i in range(peaksR.size)]))


dB = np.abs((n*L)/(2*np.sin(peaksB))) #dspacing cacualated using the Brags Equaiton
dC = np.abs((n*L)/(2*np.sin(peaksC)))
dG = np.abs((n*L)/(2*np.sin(peaksG)))
dY = np.abs((n*L)/(2*np.sin(peaksY)))
dR = np.abs((n*L)/(2*np.sin(peaksR)))

figure = make_subplots()

figure.add_trace(go.Scatter(x = waveB, y = intentB+4*r, mode= 'lines', line_color = 'blue', name = 'XRD Spectra')) #main plot
figure.add_trace(go.Scatter(x = np.array([10, 80]), y = np.array([4*r, 4*r]), line= dict(color = 'black', dash = 'dash'))) #baseline
figure.add_trace(go.Scatter(x = peaksB, y = peaksBI+4*r, mode = 'markers+text' , text = np.round(dB, 3), textposition = 'top center' , marker = dict(color = 'black', size = 6))) #marker showing peaks
figure.add_trace(go.Scatter(x = peaksB, y = peaksBI+4*r, mode = 'markers+text' , text = f'   Å', textposition = 'top right',marker = dict(color = 'black', size = 6))) #Angstrom unit position

figure.add_trace(go.Scatter(x = waveC, y = intentC+3*r, mode= 'lines', line_color = 'cyan', name = 'XRD Spectra'))
figure.add_trace(go.Scatter(x = np.array([10, 80]), y = np.array([3*r, 3*r]), line= dict(color = 'black', dash = 'dash')))
figure.add_trace(go.Scatter(x = peaksC, y = peaksCI+3*r, mode = 'markers+text' , text = np.round(dC, 3), textposition = 'top center', marker = dict(color = 'black', size = 6)))
figure.add_trace(go.Scatter(x = peaksC, y = peaksCI+3*r, mode = 'markers+text' , text = f'   Å', textposition = 'top right',marker = dict(color = 'black', size = 6)))

figure.add_trace(go.Scatter(x = waveG, y = intentG+2*r, mode= 'lines', line_color = 'green', name = 'XRD Spectra'))
figure.add_trace(go.Scatter(x = np.array([10, 80]), y = np.array([2*r, 2*r]), line= dict(color = 'black', dash = 'dash')))
figure.add_trace(go.Scatter(x = peaksG, y = peaksGI+2*r, mode = 'markers+text' ,text = np.round(dG, 3), textposition = 'top center', marker = dict(color = 'black', size = 6)))
figure.add_trace(go.Scatter(x = peaksG, y = peaksGI+2*r, mode = 'markers+text' , text = f'   Å', textposition = 'top right',marker = dict(color = 'black', size = 6)))

figure.add_trace(go.Scatter(x = waveY, y = intentY+r, mode= 'lines', line_color = 'orange', name = 'XRD Spectra'))
figure.add_trace(go.Scatter(x = np.array([10, 80]), y = np.array([r, r]), line= dict(color = 'black', dash = 'dash')))
figure.add_trace(go.Scatter(x = peaksY, y = peaksYI+r, mode = 'markers+text' ,text = np.round(dY, 3), textposition = 'top center', marker = dict(color = 'black', size = 6)))
figure.add_trace(go.Scatter(x = peaksY, y = peaksYI+r, mode = 'markers+text' , text = f'   Å', textposition = 'top right',marker = dict(color = 'black', size = 6)))

figure.add_trace(go.Scatter(x = waveR, y = intentR, mode= 'lines', line_color = 'red', name = 'XRD Spectra'))
figure.add_trace(go.Scatter(x = np.array([10, 80]), y = np.array([0, 0]), line= dict(color = 'black', dash = 'dash')))
figure.add_trace(go.Scatter(x = peaksR, y = peaksRI, mode = 'markers+text' ,text = np.round(dR, 3), textposition = 'top center', marker = dict(color = 'black', size = 6)))
figure.add_trace(go.Scatter(x = peaksR, y = peaksRI, mode = 'markers+text' ,text = f'   Å', textposition = 'top right', marker = dict(color = 'black', size = 6)))

figure.update_xaxes(title = dict(text = '2Theta', font = dict(size = 20)), ticks = 'outside', showgrid = False, showline = True, linecolor = 'black', range = [10, 80], nticks = 30, tickfont = dict(size = 16))
figure.update_yaxes(title = dict(text = 'Intensity (a.u.)', font = dict(size = 20)),  ticks = None, showgrid = False, showline = True, showticklabels = False,  linecolor = 'black', tickfont = None)
figure.update_layout(height = 600, width = 1000, showlegend = False, title = dict(text = 'XRD Spectra', font = dict(size = 20)))
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="af64e6ac-9e0a-44ca-99bb-e4aba8942545" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("af64e6ac-9e0a-44ca-99bb-e4aba8942545")) {                    Plotly.newPlot(                        "af64e6ac-9e0a-44ca-99bb-e4aba8942545",                        [{"line":{"color":"blue"},"mode":"lines","name":"XRD Spectra","x":[10.0,10.01,10.02,10.03,10.04,10.05,10.06,10.07,10.08,10.09,10.1,10.11,10.12,10.13,10.14,10.15,10.16,10.17,10.18,10.19,10.2,10.21,10.22,10.23,10.24,10.25,10.26,10.27,10.28,10.29,10.3,10.31,10.32,10.33,10.34,10.35,10.36,10.37,10.38,10.39,10.4,10.41,10.42,10.43,10.44,10.45,10.46,10.47,10.48,10.49,10.5,10.51,10.52,10.53,10.54,10.55,10.56,10.57,10.58,10.59,10.6,10.61,10.62,10.63,10.64,10.65,10.66,10.67,10.68,10.69,10.7,10.71,10.72,10.73,10.74,10.75,10.76,10.77,10.78,10.79,10.8,10.81,10.82,10.83,10.84,10.85,10.86,10.87,10.88,10.89,10.9,10.91,10.92,10.93,10.94,10.95,10.96,10.97,10.98,10.99,11.0,11.01,11.02,11.03,11.04,11.05,11.06,11.07,11.08,11.09,11.1,11.11,11.12,11.13,11.14,11.15,11.16,11.17,11.18,11.19,11.2,11.21,11.22,11.23,11.24,11.25,11.26,11.27,11.28,11.29,11.3,11.31,11.32,11.33,11.34,11.35,11.36,11.37,11.38,11.39,11.4,11.41,11.42,11.43,11.44,11.45,11.46,11.47,11.48,11.49,11.5,11.51,11.52,11.53,11.54,11.55,11.56,11.57,11.58,11.59,11.6,11.61,11.62,11.63,11.64,11.65,11.66,11.67,11.68,11.69,11.7,11.71,11.72,11.73,11.74,11.75,11.76,11.77,11.78,11.79,11.8,11.81,11.82,11.83,11.84,11.85,11.86,11.87,11.88,11.89,11.9,11.91,11.92,11.93,11.94,11.95,11.96,11.97,11.98,11.99,12.0,12.01,12.02,12.03,12.04,12.05,12.06,12.07,12.08,12.09,12.1,12.11,12.12,12.13,12.14,12.15,12.16,12.17,12.18,12.19,12.2,12.21,12.22,12.23,12.24,12.25,12.26,12.27,12.28,12.29,12.3,12.31,12.32,12.33,12.34,12.35,12.36,12.37,12.38,12.39,12.4,12.41,12.42,12.43,12.44,12.45,12.46,12.47,12.48,12.49,12.5,12.51,12.52,12.53,12.54,12.55,12.56,12.57,12.58,12.59,12.6,12.61,12.62,12.63,12.64,12.65,12.66,12.67,12.68,12.69,12.7,12.71,12.72,12.73,12.74,12.75,12.76,12.77,12.78,12.79,12.8,12.81,12.82,12.83,12.84,12.85,12.86,12.87,12.88,12.89,12.9,12.91,12.92,12.93,12.94,12.95,12.96,12.97,12.98,12.99,13.0,13.01,13.02,13.03,13.04,13.05,13.06,13.07,13.08,13.09,13.1,13.11,13.12,13.13,13.14,13.15,13.16,13.17,13.18,13.19,13.2,13.21,13.22,13.23,13.24,13.25,13.26,13.27,13.28,13.29,13.3,13.31,13.32,13.33,13.34,13.35,13.36,13.37,13.38,13.39,13.4,13.41,13.42,13.43,13.44,13.45,13.46,13.47,13.48,13.49,13.5,13.51,13.52,13.53,13.54,13.55,13.56,13.57,13.58,13.59,13.6,13.61,13.62,13.63,13.64,13.65,13.66,13.67,13.68,13.69,13.7,13.71,13.72,13.73,13.74,13.75,13.76,13.77,13.78,13.79,13.8,13.81,13.82,13.83,13.84,13.85,13.86,13.87,13.88,13.89,13.9,13.91,13.92,13.93,13.94,13.95,13.96,13.97,13.98,13.99,14.0,14.01,14.02,14.03,14.04,14.05,14.06,14.07,14.08,14.09,14.1,14.11,14.12,14.13,14.14,14.15,14.16,14.17,14.18,14.19,14.2,14.21,14.22,14.23,14.24,14.25,14.26,14.27,14.28,14.29,14.3,14.31,14.32,14.33,14.34,14.35,14.36,14.37,14.38,14.39,14.4,14.41,14.42,14.43,14.44,14.45,14.46,14.47,14.48,14.49,14.5,14.51,14.52,14.53,14.54,14.55,14.56,14.57,14.58,14.59,14.6,14.61,14.62,14.63,14.64,14.65,14.66,14.67,14.68,14.69,14.7,14.71,14.72,14.73,14.74,14.75,14.76,14.77,14.78,14.79,14.8,14.81,14.82,14.83,14.84,14.85,14.86,14.87,14.88,14.89,14.9,14.91,14.92,14.93,14.94,14.95,14.96,14.97,14.98,14.99,15.0,15.01,15.02,15.03,15.04,15.05,15.06,15.07,15.08,15.09,15.1,15.11,15.12,15.13,15.14,15.15,15.16,15.17,15.18,15.19,15.2,15.21,15.22,15.23,15.24,15.25,15.26,15.27,15.28,15.29,15.3,15.31,15.32,15.33,15.34,15.35,15.36,15.37,15.38,15.39,15.4,15.41,15.42,15.43,15.44,15.45,15.46,15.47,15.48,15.49,15.5,15.51,15.52,15.53,15.54,15.55,15.56,15.57,15.58,15.59,15.6,15.61,15.62,15.63,15.64,15.65,15.66,15.67,15.68,15.69,15.7,15.71,15.72,15.73 ...
